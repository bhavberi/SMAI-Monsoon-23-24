# %% [markdown]
# # **SMAI Assignment - 1**
# ##### (Monsoon 2023-24)
#
# > **Name**: *Bhav Beri*
# >
# > **Roll Number**: *2021111013*

# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from prettytable import PrettyTable
import time

from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# #### Configs

# %%
dataset_file = '../data.npy'

# %%
max_k = 15
random_state = 42

# %%
possible_distance_metrics = ["euclidean", "manhattan", "cosine"]
possible_weights = ["uniform", "distance"]
possible_encodings = ["resnet", "vit"]

# %%
run_distance_metrics = ["euclidean", "manhattan", "cosine"]
run_weights = ["uniform", ]
run_encodings = ["resnet", "vit"]

# %%
best_model_file_path_vit = "../best_model_vit.pkl"
best_model_file_path_resnet = "../best_model_resnet.pkl"

# %% [markdown]
# #### Utils

# %%
def euclidean_dist(pointA, pointB):
    sum = np.sum((pointA - pointB) ** 2)
    return np.sqrt(sum)

def manhattan_dist(pointA, pointB):
    return np.sum(np.abs(pointA - pointB))

def cosine_dist(pointA, pointB):
    return 1 - np.dot(pointA[0], pointB[0]) / (np.linalg.norm(pointA[0]) * np.linalg.norm(pointB[0]))

# %%
class KNN():
    def __init__(self, k: int, distance_metrics: str = "euclidean", weights: str = "uniform", encoder: str = "ResNet"):
        assert k > 0, "k must be greater than 0"
        self.k = k

        assert distance_metrics.lower() in possible_distance_metrics, "invalid distance_metrics"
        self.distance_metrics = distance_metrics.lower()
        if self.distance_metrics == "euclidean":
            self.dist_func = euclidean_dist
        elif self.distance_metrics == "manhattan":
            self.dist_func = manhattan_dist
        elif self.distance_metrics == "cosine":
            self.dist_func = cosine_dist

        assert weights.lower() in possible_weights, "invalid weights"
        self.weights = weights.lower()

        assert encoder.lower() in possible_encodings, "invalid encoder"
        self.encoder = encoder.lower()

        self.train_data = list()
        self.train_label = list()

    def fit(self, dataset):
        if self.encoder == "resnet":
            self.train_data = dataset[:,1]
        elif self.encoder == "vit":
            self.train_data = dataset[:,2]
        
        self.train_label = dataset[:,3]
    
    def predict(self, test_data):
        assert len(self.train_data) > 0, "train_data is empty"
        assert len(self.train_label) > 0, "train_label is empty"

        pred = list()
        encoder_test_data = list()
        if self.encoder == "resnet":
            encoder_test_data = test_data[:,1]
        elif self.encoder == "vit":
            encoder_test_data = test_data[:,2]
        for test in encoder_test_data:
            dist = np.array([self.dist_func(test, train) for train in self.train_data])
            idx = np.argsort(dist) # Get sorting index list

            k_labels = self.train_label[idx][:self.k]

            # Written with help from GitHub Copilot
            if self.weights == "uniform":
                unique_labels, label_counts = np.unique(k_labels, return_counts=True)
                pred.append(unique_labels[np.argmax(label_counts)])
            elif self.weights == "distance":
                k_dist = dist[idx][:self.k]
                weights = 1 / k_dist
                unique_labels, label_weights = np.unique(k_labels, return_inverse=True)
                weighted_counts = np.bincount(label_weights, weights=weights)
                pred.append(unique_labels[np.argmax(weighted_counts)])
                # label_weights = np.bincount(k_labels, weights=weights, minlength=np.max(k_labels) + 1)
                # pred.append(np.argmax(label_weights))
        return pred
    
    def scoring(self, actual_labels, pred_labels):
        f1 = f1_score(actual_labels, pred_labels, zero_division=0, average='weighted')
        accuracy = accuracy_score(actual_labels, pred_labels)
        precision = precision_score(actual_labels, pred_labels, zero_division=0, average='weighted')
        recall = recall_score(actual_labels, pred_labels, zero_division=0, average='weighted')

        # Return a dictionary of scores rounded off to 4 decimal places
        return {'f1': round(f1, 4), 'accuracy': round(accuracy, 4), 'precision': round(precision, 4), 'recall': round(recall, 4)}

# %% [markdown]
# #### Main Code

# %%
data = np.array(np.load(dataset_file, allow_pickle=True))

print("Dataset Shape - ", data.shape)
print("Data row shape",data[0].shape)

labels = data[:,3]
labels_frequency = dict()

for label in np.unique(labels):
    labels_frequency[label] = np.sum(labels == label)

print("Max Frequency Label:", max(labels_frequency, key=labels_frequency.get), "with Value =", max(labels_frequency.values()))
print("Min Frequency Label:", min(labels_frequency, key=labels_frequency.get), "with Value =", min(labels_frequency.values()))       

fig, axs = plt.subplots(2,1, figsize=(30, 40))

axs[0].bar(list(labels_frequency.keys()), list(labels_frequency.values()))
axs[0].set_xlabel('Labels')
axs[0].set_ylabel('Frequency')

axs[1].scatter(list(labels_frequency.keys()), list(labels_frequency.values()))
axs[1].set_xlabel('Labels')
axs[1].set_ylabel('Frequency')
plt.show()
# Out:
# Dataset Shape -  (1500, 5)
# Data row shape (5,)
# Max Frequency Label: flute with Value = 26
# Min Frequency Label: dig with Value = 1

# %%
# Prepare Data

data_train, data_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=random_state)

# %%
# Get all possible combinations of hyperparameters
all_scores = list()

for k in range(1, max_k + 1):
    for distance_metrics in run_distance_metrics:
        for weights in run_weights:
            for encoder in run_encodings:
                print("k =", k, "| distance_metrics =", distance_metrics, "| weights =", weights, "| encoder =", encoder)
                knn = KNN(k=k, distance_metrics=distance_metrics, weights=weights, encoder=encoder)
                knn.fit(data_train)
                start = time.time()
                pred = knn.predict(data_test)
                end = time.time()
                score = knn.scoring(y_test, pred)
                time_taken = end - start
                print("Time:", time_taken, "s")
                print("Score:", score)
                print("")
                score["time"] = time_taken
                all_scores.append([score, k, distance_metrics, weights, encoder])
# Out:
# k = 1 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 4.535066366195679 s
# Score: {'f1': 0.1838, 'accuracy': 0.1867, 'precision': 0.2191, 'recall': 0.1867}
#
# k = 1 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.780280113220215 s
# Score: {'f1': 0.2552, 'accuracy': 0.27, 'precision': 0.2778, 'recall': 0.27}
#
# k = 1 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.9714605808258057 s
# Score: {'f1': 0.1846, 'accuracy': 0.1867, 'precision': 0.2186, 'recall': 0.1867}
#
# k = 1 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.495236873626709 s
# Score: {'f1': 0.2633, 'accuracy': 0.2767, 'precision': 0.3037, 'recall': 0.2767}
#
# k = 1 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.1308434009552 s
# Score: {'f1': 0.197, 'accuracy': 0.2033, 'precision': 0.24, 'recall': 0.2033}
#
# k = 1 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.836522102355957 s
# Score: {'f1': 0.244, 'accuracy': 0.26, 'precision': 0.2604, 'recall': 0.26}
#
# k = 2 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.782181978225708 s
# Score: {'f1': 0.1225, 'accuracy': 0.1333, 'precision': 0.1619, 'recall': 0.1333}
#
# k = 2 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.003870725631714 s
# Score: {'f1': 0.2158, 'accuracy': 0.2333, 'precision': 0.2571, 'recall': 0.2333}
#
# k = 2 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.3028273582458496 s
# Score: {'f1': 0.1348, 'accuracy': 0.1467, 'precision': 0.1493, 'recall': 0.1467}
#
# k = 2 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 3.0192010402679443 s
# Score: {'f1': 0.2081, 'accuracy': 0.23, 'precision': 0.2274, 'recall': 0.23}
#
# k = 2 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 5.129236698150635 s
# Score: {'f1': 0.1259, 'accuracy': 0.1367, 'precision': 0.1527, 'recall': 0.1367}
#
# k = 2 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.405097246170044 s
# Score: {'f1': 0.2125, 'accuracy': 0.2367, 'precision': 0.2308, 'recall': 0.2367}
#
# k = 3 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.4598655700683594 s
# Score: {'f1': 0.1493, 'accuracy': 0.1533, 'precision': 0.1861, 'recall': 0.1533}
#
# k = 3 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.190424919128418 s
# Score: {'f1': 0.1906, 'accuracy': 0.2133, 'precision': 0.2224, 'recall': 0.2133}
#
# k = 3 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.194748640060425 s
# Score: {'f1': 0.1487, 'accuracy': 0.16, 'precision': 0.1721, 'recall': 0.16}
#
# k = 3 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 3.1559298038482666 s
# Score: {'f1': 0.2073, 'accuracy': 0.2267, 'precision': 0.2536, 'recall': 0.2267}
#
# k = 3 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.829048156738281 s
# Score: {'f1': 0.1543, 'accuracy': 0.16, 'precision': 0.1895, 'recall': 0.16}
#
# k = 3 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.420374393463135 s
# Score: {'f1': 0.185, 'accuracy': 0.2033, 'precision': 0.2148, 'recall': 0.2033}
#
# k = 4 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.000339984893799 s
# Score: {'f1': 0.1421, 'accuracy': 0.1533, 'precision': 0.1571, 'recall': 0.1533}
#
# k = 4 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.6299116611480713 s
# Score: {'f1': 0.2005, 'accuracy': 0.22, 'precision': 0.2423, 'recall': 0.22}
#
# k = 4 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.9050068855285645 s
# Score: {'f1': 0.1659, 'accuracy': 0.1767, 'precision': 0.195, 'recall': 0.1767}
#
# k = 4 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 3.437150001525879 s
# Score: {'f1': 0.2145, 'accuracy': 0.2333, 'precision': 0.2599, 'recall': 0.2333}
#
# k = 4 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.0963335037231445 s
# Score: {'f1': 0.1548, 'accuracy': 0.1633, 'precision': 0.1832, 'recall': 0.1633}
#
# k = 4 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.49124002456665 s
# Score: {'f1': 0.1942, 'accuracy': 0.2133, 'precision': 0.2276, 'recall': 0.2133}
#
# k = 5 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.5235695838928223 s
# Score: {'f1': 0.154, 'accuracy': 0.1667, 'precision': 0.18, 'recall': 0.1667}
#
# k = 5 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.1342387199401855 s
# Score: {'f1': 0.1941, 'accuracy': 0.2133, 'precision': 0.239, 'recall': 0.2133}
#
# k = 5 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.9065892696380615 s
# Score: {'f1': 0.1722, 'accuracy': 0.19, 'precision': 0.1937, 'recall': 0.19}
#
# k = 5 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.8485641479492188 s
# Score: {'f1': 0.2016, 'accuracy': 0.2233, 'precision': 0.2366, 'recall': 0.2233}
#
# k = 5 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.261516332626343 s
# Score: {'f1': 0.1424, 'accuracy': 0.1533, 'precision': 0.1693, 'recall': 0.1533}
#
# k = 5 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.112405300140381 s
# Score: {'f1': 0.2026, 'accuracy': 0.2167, 'precision': 0.248, 'recall': 0.2167}
#
# k = 6 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.508221387863159 s
# Score: {'f1': 0.1426, 'accuracy': 0.16, 'precision': 0.1673, 'recall': 0.16}
#
# k = 6 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.151776075363159 s
# Score: {'f1': 0.183, 'accuracy': 0.2, 'precision': 0.206, 'recall': 0.2}
#
# k = 6 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.17746901512146 s
# Score: {'f1': 0.1796, 'accuracy': 0.1967, 'precision': 0.2046, 'recall': 0.1967}
#
# k = 6 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.514280319213867 s
# Score: {'f1': 0.2005, 'accuracy': 0.22, 'precision': 0.2386, 'recall': 0.22}
#
# k = 6 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.105729579925537 s
# Score: {'f1': 0.1519, 'accuracy': 0.1633, 'precision': 0.184, 'recall': 0.1633}
#
# k = 6 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.9464402198791504 s
# Score: {'f1': 0.2008, 'accuracy': 0.2167, 'precision': 0.2421, 'recall': 0.2167}
#
# k = 7 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.3919289112091064 s
# Score: {'f1': 0.1408, 'accuracy': 0.1567, 'precision': 0.1688, 'recall': 0.1567}
#
# k = 7 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.048179864883423 s
# Score: {'f1': 0.2002, 'accuracy': 0.22, 'precision': 0.2243, 'recall': 0.22}
#
# k = 7 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.8996386528015137 s
# Score: {'f1': 0.1708, 'accuracy': 0.19, 'precision': 0.1979, 'recall': 0.19}
#
# k = 7 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.5634706020355225 s
# Score: {'f1': 0.2022, 'accuracy': 0.2267, 'precision': 0.2354, 'recall': 0.2267}
#
# k = 7 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.189656734466553 s
# Score: {'f1': 0.1581, 'accuracy': 0.1733, 'precision': 0.195, 'recall': 0.1733}
#
# k = 7 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.7482423782348633 s
# Score: {'f1': 0.1943, 'accuracy': 0.2133, 'precision': 0.2276, 'recall': 0.2133}
#
# k = 8 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.2316083908081055 s
# Score: {'f1': 0.1473, 'accuracy': 0.1667, 'precision': 0.173, 'recall': 0.1667}
#
# k = 8 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.197510004043579 s
# Score: {'f1': 0.1977, 'accuracy': 0.2167, 'precision': 0.2338, 'recall': 0.2167}
#
# k = 8 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.9330368041992188 s
# Score: {'f1': 0.1857, 'accuracy': 0.2033, 'precision': 0.2117, 'recall': 0.2033}
#
# k = 8 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.7130303382873535 s
# Score: {'f1': 0.2071, 'accuracy': 0.2333, 'precision': 0.2286, 'recall': 0.2333}
#
# k = 8 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 3.992438793182373 s
# Score: {'f1': 0.1484, 'accuracy': 0.1667, 'precision': 0.1753, 'recall': 0.1667}
#
# k = 8 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.750084638595581 s
# Score: {'f1': 0.1935, 'accuracy': 0.2133, 'precision': 0.2136, 'recall': 0.2133}
#
# k = 9 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.4295284748077393 s
# Score: {'f1': 0.1417, 'accuracy': 0.16, 'precision': 0.1667, 'recall': 0.16}
#
# k = 9 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.050597667694092 s
# Score: {'f1': 0.2029, 'accuracy': 0.22, 'precision': 0.2642, 'recall': 0.22}
#
# k = 9 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.963092565536499 s
# Score: {'f1': 0.1878, 'accuracy': 0.21, 'precision': 0.2102, 'recall': 0.21}
#
# k = 9 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.572260856628418 s
# Score: {'f1': 0.2051, 'accuracy': 0.2267, 'precision': 0.2577, 'recall': 0.2267}
#
# k = 9 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.228344202041626 s
# Score: {'f1': 0.1482, 'accuracy': 0.1667, 'precision': 0.1685, 'recall': 0.1667}
#
# k = 9 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.802720546722412 s
# Score: {'f1': 0.1885, 'accuracy': 0.2167, 'precision': 0.2171, 'recall': 0.2167}
#
# k = 10 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.470456838607788 s
# Score: {'f1': 0.1565, 'accuracy': 0.1767, 'precision': 0.178, 'recall': 0.1767}
#
# k = 10 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.095907688140869 s
# Score: {'f1': 0.1978, 'accuracy': 0.22, 'precision': 0.2541, 'recall': 0.22}
#
# k = 10 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.9475598335266113 s
# Score: {'f1': 0.1818, 'accuracy': 0.2067, 'precision': 0.2058, 'recall': 0.2067}
#
# k = 10 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.6581389904022217 s
# Score: {'f1': 0.2093, 'accuracy': 0.2333, 'precision': 0.253, 'recall': 0.2333}
#
# k = 10 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.026813507080078 s
# Score: {'f1': 0.1582, 'accuracy': 0.1767, 'precision': 0.1753, 'recall': 0.1767}
#
# k = 10 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.739687204360962 s
# Score: {'f1': 0.1876, 'accuracy': 0.21, 'precision': 0.2205, 'recall': 0.21}
#
# k = 11 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.425177812576294 s
# Score: {'f1': 0.1662, 'accuracy': 0.1833, 'precision': 0.1848, 'recall': 0.1833}
#
# k = 11 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.1567280292510986 s
# Score: {'f1': 0.2062, 'accuracy': 0.23, 'precision': 0.2449, 'recall': 0.23}
#
# k = 11 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.002068281173706 s
# Score: {'f1': 0.1799, 'accuracy': 0.2067, 'precision': 0.2033, 'recall': 0.2067}
#
# k = 11 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 3.0473062992095947 s
# Score: {'f1': 0.2233, 'accuracy': 0.2467, 'precision': 0.2765, 'recall': 0.2467}
#
# k = 11 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.765601634979248 s
# Score: {'f1': 0.1537, 'accuracy': 0.1733, 'precision': 0.1762, 'recall': 0.1733}
#
# k = 11 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.149135112762451 s
# Score: {'f1': 0.1953, 'accuracy': 0.2167, 'precision': 0.23, 'recall': 0.2167}
#
# k = 12 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.796560764312744 s
# Score: {'f1': 0.1612, 'accuracy': 0.1767, 'precision': 0.182, 'recall': 0.1767}
#
# k = 12 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.0669877529144287 s
# Score: {'f1': 0.2032, 'accuracy': 0.2267, 'precision': 0.2475, 'recall': 0.2267}
#
# k = 12 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 3.261478900909424 s
# Score: {'f1': 0.1796, 'accuracy': 0.2067, 'precision': 0.1972, 'recall': 0.2067}
#
# k = 12 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 3.0085222721099854 s
# Score: {'f1': 0.2305, 'accuracy': 0.26, 'precision': 0.268, 'recall': 0.26}
#
# k = 12 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.7674925327301025 s
# Score: {'f1': 0.1592, 'accuracy': 0.1767, 'precision': 0.1806, 'recall': 0.1767}
#
# k = 12 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 4.806158065795898 s
# Score: {'f1': 0.2018, 'accuracy': 0.23, 'precision': 0.2329, 'recall': 0.23}
#
# k = 13 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.7133936882019043 s
# Score: {'f1': 0.174, 'accuracy': 0.19, 'precision': 0.1987, 'recall': 0.19}
#
# k = 13 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.017789602279663 s
# Score: {'f1': 0.1929, 'accuracy': 0.22, 'precision': 0.2291, 'recall': 0.22}
#
# k = 13 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.871995449066162 s
# Score: {'f1': 0.1789, 'accuracy': 0.2033, 'precision': 0.2022, 'recall': 0.2033}
#
# k = 13 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.621579885482788 s
# Score: {'f1': 0.2193, 'accuracy': 0.2533, 'precision': 0.2471, 'recall': 0.2533}
#
# k = 13 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.194281339645386 s
# Score: {'f1': 0.164, 'accuracy': 0.1833, 'precision': 0.1849, 'recall': 0.1833}
#
# k = 13 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.712615728378296 s
# Score: {'f1': 0.2037, 'accuracy': 0.23, 'precision': 0.2385, 'recall': 0.23}
#
# k = 14 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 3.1785058975219727 s
# Score: {'f1': 0.1775, 'accuracy': 0.1933, 'precision': 0.2023, 'recall': 0.1933}
#
# k = 14 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 2.8750669956207275 s
# Score: {'f1': 0.1914, 'accuracy': 0.22, 'precision': 0.2144, 'recall': 0.22}
#
# k = 14 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.650438070297241 s
# Score: {'f1': 0.1713, 'accuracy': 0.1933, 'precision': 0.1958, 'recall': 0.1933}
#
# k = 14 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.3682336807250977 s
# Score: {'f1': 0.2173, 'accuracy': 0.2533, 'precision': 0.2387, 'recall': 0.2533}
#
# k = 14 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 3.8505663871765137 s
# Score: {'f1': 0.1492, 'accuracy': 0.17, 'precision': 0.1695, 'recall': 0.17}
#
# k = 14 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.856980085372925 s
# Score: {'f1': 0.1987, 'accuracy': 0.2267, 'precision': 0.227, 'recall': 0.2267}
#
# k = 15 | distance_metrics = euclidean | weights = uniform | encoder = resnet
# Time: 4.015082836151123 s
# Score: {'f1': 0.1704, 'accuracy': 0.1833, 'precision': 0.198, 'recall': 0.1833}
#
# k = 15 | distance_metrics = euclidean | weights = uniform | encoder = vit
# Time: 3.332813262939453 s
# Score: {'f1': 0.1906, 'accuracy': 0.22, 'precision': 0.2053, 'recall': 0.22}
#
# k = 15 | distance_metrics = manhattan | weights = uniform | encoder = resnet
# Time: 2.9231910705566406 s
# Score: {'f1': 0.175, 'accuracy': 0.2, 'precision': 0.1867, 'recall': 0.2}
#
# k = 15 | distance_metrics = manhattan | weights = uniform | encoder = vit
# Time: 2.7300167083740234 s
# Score: {'f1': 0.2048, 'accuracy': 0.2433, 'precision': 0.225, 'recall': 0.2433}
#
# k = 15 | distance_metrics = cosine | weights = uniform | encoder = resnet
# Time: 4.066299200057983 s
# Score: {'f1': 0.1436, 'accuracy': 0.17, 'precision': 0.1507, 'recall': 0.17}
#
# k = 15 | distance_metrics = cosine | weights = uniform | encoder = vit
# Time: 3.936768054962158 s
# Score: {'f1': 0.1927, 'accuracy': 0.2267, 'precision': 0.2079, 'recall': 0.2267}

# %%
# Sort the combinations based on accuracy score
all_scores.sort(key=lambda x: x[0]["accuracy"], reverse=True)

# %%
# Best Model

best_model = KNN(k=all_scores[0][1], distance_metrics=all_scores[0][2], weights=all_scores[0][3], encoder=all_scores[0][4])
best_model.fit(data_train)

print("Best Triplet:")
print("k =", all_scores[0][1], "distance_metrics =", all_scores[0][2], "weights =", all_scores[0][3], "encoder =", all_scores[0][4])
print("Score:", all_scores[0][0])
# Out:
# Best Triplet:
# k = 1 distance_metrics = manhattan weights = uniform encoder = vit
# Score: {'f1': 0.2633, 'accuracy': 0.2767, 'precision': 0.3037, 'recall': 0.2767, 'time': 2.495236873626709}

# %%
# Save & Check the Best Model Saved for VIT

all_scores_vit = [score for score in all_scores if score[4] == "vit"]
all_scores_vit.sort(key=lambda x: x[0]["accuracy"], reverse=True)

best_model_vit = KNN(k=all_scores_vit[0][1], distance_metrics=all_scores_vit[0][2], weights=all_scores_vit[0][3], encoder=all_scores_vit[0][4])
best_model_vit.fit(data_train)

# Save the best model for encoder=vit
fp = open(best_model_file_path_vit, "wb+")
pickle.dump(best_model_vit, fp)
fp.close()

# Load the best model for encoder=vit
fp = open(best_model_file_path_vit, "rb")
best_model_vit = pickle.load(fp)
fp.close()

# Predict using the best model for encoder=vit
pred = best_model_vit.predict(data_test)
scores = best_model_vit.scoring(y_test, pred)
old_scores = all_scores_vit[0][0].copy()
del old_scores['time']

print("VIT -", scores == old_scores)
# Out:
# VIT - True

# %%
# Save & Check the Best Model Saved for ResNet

all_scores_resnet = [score for score in all_scores if score[4] == "resnet"]
all_scores_resnet.sort(key=lambda x: x[0]["accuracy"], reverse=True)

best_model_resnet = KNN(k=all_scores_resnet[0][1], distance_metrics=all_scores_resnet[0][2], weights=all_scores_resnet[0][3], encoder=all_scores_resnet[0][4])
best_model_resnet.fit(data_train)

# Save the best model for encoder=resnet
fp = open(best_model_file_path_resnet, "wb+")
pickle.dump(best_model_resnet, fp)
fp.close()

# Load the best model for encoder=resnet
fp = open(best_model_file_path_resnet, "rb")
best_model_resnet = pickle.load(fp)
fp.close()

# Predict using the best model for encoder=resnet
pred = best_model_resnet.predict(data_test)
scores = best_model_resnet.scoring(y_test, pred)
old_scores = all_scores_resnet[0][0].copy()
del old_scores['time']

print("ResNet -", scores == old_scores)
# Out:
# ResNet - True

# %%
# Top 20 triplets in a table format

print("Top 20 Triplets:")

print(all_scores[0][0])

x = PrettyTable()
x.field_names = ["Rank", "k", "distance_metrics", "weights", "encoder", "accuracy", "f1", "precision", "recall", "time"]
x.add_rows([[i+1, all_scores[i][1], all_scores[i][2], all_scores[i][3], all_scores[i][4], all_scores[i][0]["accuracy"], all_scores[i][0]["f1"], all_scores[i][0]["precision"], all_scores[i][0]["recall"], all_scores[i][0]["time"]] for i in range(20)])
print(x)
# Out:
# Top 20 Triplets:
# {'f1': 0.2633, 'accuracy': 0.2767, 'precision': 0.3037, 'recall': 0.2767, 'time': 2.495236873626709}
# +------+----+------------------+---------+---------+----------+--------+-----------+--------+--------------------+
# | Rank | k  | distance_metrics | weights | encoder | accuracy |   f1   | precision | recall |        time        |
# +------+----+------------------+---------+---------+----------+--------+-----------+--------+--------------------+
# |  1   | 1  |    manhattan     | uniform |   vit   |  0.2767  | 0.2633 |   0.3037  | 0.2767 | 2.495236873626709  |
# |  2   | 1  |    euclidean     | uniform |   vit   |   0.27   | 0.2552 |   0.2778  |  0.27  | 3.780280113220215  |
# |  3   | 1  |      cosine      | uniform |   vit   |   0.26   | 0.244  |   0.2604  |  0.26  | 3.836522102355957  |
# |  4   | 12 |    manhattan     | uniform |   vit   |   0.26   | 0.2305 |   0.268   |  0.26  | 3.0085222721099854 |
# |  5   | 13 |    manhattan     | uniform |   vit   |  0.2533  | 0.2193 |   0.2471  | 0.2533 | 2.621579885482788  |
# |  6   | 14 |    manhattan     | uniform |   vit   |  0.2533  | 0.2173 |   0.2387  | 0.2533 | 2.3682336807250977 |
# |  7   | 11 |    manhattan     | uniform |   vit   |  0.2467  | 0.2233 |   0.2765  | 0.2467 | 3.0473062992095947 |
# |  8   | 15 |    manhattan     | uniform |   vit   |  0.2433  | 0.2048 |   0.225   | 0.2433 | 2.7300167083740234 |
# |  9   | 2  |      cosine      | uniform |   vit   |  0.2367  | 0.2125 |   0.2308  | 0.2367 | 4.405097246170044  |
# |  10  | 2  |    euclidean     | uniform |   vit   |  0.2333  | 0.2158 |   0.2571  | 0.2333 | 3.003870725631714  |
# |  11  | 4  |    manhattan     | uniform |   vit   |  0.2333  | 0.2145 |   0.2599  | 0.2333 | 3.437150001525879  |
# |  12  | 8  |    manhattan     | uniform |   vit   |  0.2333  | 0.2071 |   0.2286  | 0.2333 | 2.7130303382873535 |
# |  13  | 10 |    manhattan     | uniform |   vit   |  0.2333  | 0.2093 |   0.253   | 0.2333 | 2.6581389904022217 |
# |  14  | 2  |    manhattan     | uniform |   vit   |   0.23   | 0.2081 |   0.2274  |  0.23  | 3.0192010402679443 |
# |  15  | 11 |    euclidean     | uniform |   vit   |   0.23   | 0.2062 |   0.2449  |  0.23  | 3.1567280292510986 |
# |  16  | 12 |      cosine      | uniform |   vit   |   0.23   | 0.2018 |   0.2329  |  0.23  | 4.806158065795898  |
# |  17  | 13 |      cosine      | uniform |   vit   |   0.23   | 0.2037 |   0.2385  |  0.23  | 3.712615728378296  |
# |  18  | 3  |    manhattan     | uniform |   vit   |  0.2267  | 0.2073 |   0.2536  | 0.2267 | 3.1559298038482666 |
# |  19  | 7  |    manhattan     | uniform |   vit   |  0.2267  | 0.2022 |   0.2354  | 0.2267 | 2.5634706020355225 |
# |  20  | 9  |    manhattan     | uniform |   vit   |  0.2267  | 0.2051 |   0.2577  | 0.2267 | 2.572260856628418  |
# +------+----+------------------+---------+---------+----------+--------+-----------+--------+--------------------+

# %%
# Plot k vs accuracy for a fixed distance_metrics, weights and encoder

encoder = "vit"
distance_metrics = "manhattan"
weights = "uniform"
k = [all_scores[i][1] for i in range(len(all_scores)) if all_scores[i][2] == distance_metrics and all_scores[i][3] == weights and all_scores[i][4] == encoder]
accuracy = [all_scores[i][0]["accuracy"] for i in range(len(all_scores)) if all_scores[i][2] == distance_metrics and all_scores[i][3] == weights and all_scores[i][4] == encoder]

plt.figure(figsize=(10, 7))
plt.scatter(k, accuracy, color='red')
plt.xlabel("k")
plt.ylabel("accuracy")
plt.title("k vs accuracy for distance_metrics = " + distance_metrics + " | weights = " + weights + " | encoder = " + encoder)
plt.show()

# %%
# Plot inference time for initial KNN model, best KNN model, most optimized KNN model, and the default sklearn KNN model

# Best KNN model
best_inference_time = all_scores[0][0]["time"]

# Sort the combinations based on time
all_scores_copy = all_scores.copy()
all_scores_copy.sort(key=lambda x: x[0]["time"])
optimized_inference_time = all_scores_copy[0][0]["time"]
optimized_model = KNN(k=all_scores_copy[0][1], distance_metrics=all_scores_copy[0][2], weights=all_scores_copy[0][3], encoder=all_scores_copy[0][4])

# Initial KNN model
initial_model = KNN(k=1, distance_metrics="euclidean", weights="uniform", encoder="resnet")
initial_inference_time = 0
for elem in all_scores:
    if elem[1] == 1 and elem[2] == "euclidean" and elem[3] == "uniform" and elem[4] == "resnet":
        initial_inference_time = elem[0]["time"]
        break

# Default sklearn KNN model
data_train_vit, data_test_vit = [],[]

for i in data_train:
    data_train_vit.append(i[2].reshape(-1))

for i in data_test:
    data_test_vit.append(i[2].reshape(-1))

knn = KNeighborsClassifier(n_neighbors=all_scores[0][1])
knn.fit(data_train_vit, y_train) # type: ignore
start = time.time()
pred = knn.predict(data_test_vit) # type: ignore
end = time.time()
sklearn_inference_time = end - start

classes = ['Initial', 'Best', 'Optimized', 'Sklearn']
inference_times = [initial_inference_time, best_inference_time, optimized_inference_time, sklearn_inference_time]

plt.figure(figsize=(10, 7))
plt.scatter(classes, inference_times, color='green')
plt.xlabel("Models")
plt.ylabel("Inference Times")
plt.title("Inference Times for Initial KNN model, Best KNN model, Optimized KNN model, and the Default sklearn KNN model")
plt.show()

# %%
x = []
best_inference_times = []
optimized_inference_times = []
initial_inference_times = []
sklearn_inference_times = []

for i in range(1, data_train.shape[0]+1, 100):
    best_model.fit(data_train[:i])
    optimized_model.fit(data_train[:i])
    initial_model.fit(data_train[:i])

    data_train_vit, data_test_vit = [],[]
    y_train_vit = [i[3] for i in data_train[:i]]

    for j in data_train[:i]:
        data_train_vit.append(j[2].reshape(-1))

    for j in data_test:
        data_test_vit.append(j[2].reshape(-1))

    knn = KNeighborsClassifier(n_neighbors=all_scores[0][1])
    knn.fit(data_train_vit, y_train_vit) # type: ignore

    # Calculate Times
    start = time.time()
    pred = best_model.predict(data_test)
    end = time.time()
    best_inference_time = end - start

    start = time.time()
    pred = optimized_model.predict(data_test)
    end = time.time()
    optimized_inference_time = end - start

    start = time.time()
    pred = initial_model.predict(data_test)
    end = time.time()
    initial_inference_time = end - start

    start = time.time()
    pred = knn.predict(data_test_vit) # type: ignore
    end = time.time()
    sklearn_inference_time = end - start

    x.append(i)
    best_inference_times.append(best_inference_time)
    optimized_inference_times.append(optimized_inference_time)
    initial_inference_times.append(initial_inference_time)
    sklearn_inference_times.append(sklearn_inference_time)

# %%
plt.plot(x, best_inference_times, label="Best")
plt.plot(x, optimized_inference_times, label="Optimized")
plt.plot(x, initial_inference_times, label="Initial")
plt.plot(x, sklearn_inference_times, label="Sklearn")
plt.xlabel("Training Data Size")
plt.ylabel("Inference Times")
plt.legend()
plt.show()
